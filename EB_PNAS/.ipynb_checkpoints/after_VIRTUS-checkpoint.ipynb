# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
np.random.seed(100)
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib as mpl
mpl.rcParams['figure.facecolor'] = (1,1,1,1)

# %%
df = pd.read_csv('NC0070605.1.counts.tsv', sep=' ', index_col=0)
df.head()
# Out:
#        donor1_day0  donor1_day1  donor1_day2  donor1_day3  donor1_day4  \
# A73            0.0        2.000       13.692       15.153       28.217
# BALF1          0.0        4.000        0.000        2.000        2.000
# BALF2          0.0       10.000        7.000       24.000        4.000
# BALF3          3.0        0.000       75.993      151.938      140.094
# BALF4          0.0       22.016       42.004       94.317       81.114
#
#        donor1_day5  donor1_day8  donor1_day14  donor2_day0  donor2_day1  \
# A73         28.887       49.697        18.000          0.0        0.000
# BALF1        0.000        9.000         2.000          0.0        0.000
# BALF2        5.000      112.000         3.000          0.0        8.000
# BALF3      275.597      380.035       105.907          4.0       32.745
# BALF4      120.785      204.913        30.627          0.0       20.963
#
#            ...       donor2_day8  donor2_day14  donor3_day0  donor3_day1  \
# A73        ...            34.868        23.544          0.0        1.065
# BALF1      ...             0.000         1.000          0.0        3.000
# BALF2      ...            19.000         0.000          1.0        0.000
# BALF3      ...           135.654       128.404          2.0       49.000
# BALF4      ...            35.764        41.052          0.0       17.000
#
#        donor3_day2  donor3_day3  donor3_day4  donor3_day5  donor3_day8  \
# A73          6.927       15.916       21.428       42.320       27.865
# BALF1        0.000        0.000        6.000        6.000        2.000
# BALF2        4.000       14.000       14.000       17.000        7.000
# BALF3       48.581       87.547      141.428      277.724      101.049
# BALF4       41.357       46.537       63.602      101.603       42.025
#
#        donor3_day14
# A73          13.000
# BALF1         3.000
# BALF2        12.000
# BALF3       142.204
# BALF4        76.796
#
# [5 rows x 24 columns]

# %%
print(' -e '.join(df.sum(axis=1).sort_values(ascending=False).head(20).index))
# Out:
# BWRF1 -e EBNA-2 -e EBNA-LP -e EBNA-1 -e EBNA-3B/EBNA-3C -e BHRF1 -e EBNA-3A -e LMP-1 -e BZLF2 -e BPLF1 -e BALF3 -e BTRF1 -e BORF2 -e BcRF1 -e BXLF2 -e BLLF1 -e BALF5 -e LMP-2A -e BKRF4 -e BNRF1

# %%
print(' -e '.join(df.sum(axis=1).sort_values(ascending=False).head(10).index))
# Out:
# BWRF1 -e EBNA-2 -e EBNA-LP -e EBNA-1 -e EBNA-3B/EBNA-3C -e BHRF1 -e EBNA-3A -e LMP-1 -e BZLF2 -e BPLF1

# %%
print(' -e '.join(df.sum(axis=1).sort_values(ascending=False).head(5).index))
# Out:
# BWRF1 -e EBNA-2 -e EBNA-LP -e EBNA-1 -e EBNA-3B/EBNA-3C

# %% [markdown]
# ## coverage

# %%
df_exon = pd.read_csv('exon.cov.txt', sep=' ', header=None)
df_exon.columns = ['exon']

df_nonexon = pd.read_csv('nonexon.cov.txt', sep=' ', header=None)
df_nonexon.columns = ['non exon']

df_genome = pd.read_csv('genome.cov.txt', sep=' ', header=None)
df_genome.columns = ['genome', 'sample']
df_genome['sample'] = df_genome['sample'].str.split('/').str.get(1).str.split('.').str.get(0)
df_genome['donor'] = df_genome['sample'].str.split('_').str.get(0)
df_genome['day'] = df_genome['sample'].str.split('_').str.get(1)

df_genome['exon'] = df_exon['exon']
df_genome['non exon'] = df_nonexon['non exon']
df_genome['exon coverage'] = df_genome['exon'] / df_genome['genome']
df_genome['non exon coverage'] = df_genome['non exon'] / df_genome['genome']

df_genome
# Out:
#     genome        sample   donor    day    exon  non exon  exon coverage  \
# 0     1794   donor1_day0  donor1   day0    1208       965       0.673356
# 1   177175   donor1_day1  donor1   day1  127808     87097       0.721366
# 2   117548   donor1_day2  donor1   day2   80117     63878       0.681568
# 3    69940   donor1_day3  donor1   day3   46474     39128       0.664484
# 4    46368   donor1_day4  donor1   day4   31680     25354       0.683230
# 5    49222   donor1_day5  donor1   day5   30875     29437       0.627260
# 6   135020   donor1_day8  donor1   day8   85307     78839       0.631810
# 7    43384  donor1_day14  donor1  day14   28516     25016       0.657293
# 8     1282   donor2_day0  donor2   day0     900       671       0.702028
# 9   122212   donor2_day1  donor2   day1   82556     68108       0.675515
# 10   80380   donor2_day2  donor2   day2   56575     42319       0.703844
# 11   55188   donor2_day3  donor2   day3   38955     28672       0.705860
# 12   55390   donor2_day4  donor2   day4   36959     30695       0.667250
# 13   44346   donor2_day5  donor2   day5   29151     24789       0.657354
# 14   41902   donor2_day8  donor2   day8   29527     22081       0.704668
# 15   49082  donor2_day14  donor2  day14   33041     27219       0.673180
# 16     894   donor3_day0  donor3   day0     607       433       0.678971
# 17  129924   donor3_day1  donor3   day1   86950     71783       0.669237
# 18   89843   donor3_day2  donor3   day2   61984     48463       0.689915
# 19   48882   donor3_day3  donor3   day3   34315     25723       0.701997
# 20   45174   donor3_day4  donor3   day4   31429     24894       0.695732
# 21   73658   donor3_day5  donor3   day5   46723     43587       0.634323
# 22   38498   donor3_day8  donor3   day8   26146     21388       0.679152
# 23   17000  donor3_day14  donor3  day14   11895      8846       0.699706
#
#     non exon coverage
# 0            0.537904
# 1            0.491587
# 2            0.543421
# 3            0.559451
# 4            0.546800
# 5            0.598046
# 6            0.583906
# 7            0.576618
# 8            0.523401
# 9            0.557294
# 10           0.526487
# 11           0.519533
# 12           0.554161
# 13           0.558991
# 14           0.526968
# 15           0.554562
# 16           0.484340
# 17           0.552500
# 18           0.539419
# 19           0.526226
# 20           0.551069
# 21           0.591748
# 22           0.555561
# 23           0.520353

# %%
d1 = df_genome[['day', 'exon coverage']]
d1.columns = ['day', 'coverage']
d1['region'] = 'exon'

d2 = df_genome[['day', 'non exon coverage']]
d2.columns = ['day', 'coverage']
d2['region'] = 'non exon'

d = pd.concat([d1, d2])
# Out:
# /Users/yasumizuyoshiaki/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/yasumizuyoshiaki/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   import sys

# %%
sns.swarmplot(data=d, y="coverage", x="day", hue="region")
plt.ylim(0,1)
# plt.savefig('coverage.pdf')
# Out:
# (0, 1)

# %%
sns.swarmplot(data=df_genome, y="coverage", x="day")
plt.ylim(0,1)
plt.savefig('exon.coverage.pdf')

# %% [markdown]
# ## Virtect

# %%
list_donors = ['1', '2', '3']
# list_days = ['0', '1', '2', '3', '4', '5', '8', '14']
list_days = ['0', '1', '2', '3', '4', '5', '8']

# %%
for donor in list_donors:
    for day in list_days:
        s = "donor{don}_day{day}".format(don=donor, day=day)
        d = pd.read_csv('Virtect_output/output/{}.txt'.format(s), delim_whitespace=True, skiprows=1, header=None)
        d.columns = [s, 'virus']
        d = d[d[s] > 400]
        
        if s == "donor1_day0":
            df_virtect = d.copy()
        else:
            df_virtect = pd.merge(df_virtect, d, how="outer")
df_virtect = df_virtect.fillna(0)

df_virtect.index = df_virtect.virus
# df_virtect = df_virtect.drop('virus')
df_virtect = df_virtect.drop(columns=['virus'])
df_virtect = df_virtect.sort_values(by='donor1_day1', ascending=False)
df_virtect.head()
# Out:
#                                                     donor1_day0  donor1_day1  \
# virus
# NC_009823.1_Hepatitis_C_virus_genotype_2,_compl...    5525018.0    6101557.0
# NC_004102.1_Hepatitis_C_virus_genotype_1,_compl...    1431200.0    1309365.0
# NC_001672.1_Tick-borne_encephalitis_virus,_comp...     863167.0     871020.0
# NC_009827.1_Hepatitis_C_virus_genotype_6,_compl...     767062.0     813529.0
# NC_015521.1_Cutthroat_trout_virus,_complete_genome     414053.0     414937.0
#
#                                                     donor1_day2  donor2_day0  \
# virus
# NC_009823.1_Hepatitis_C_virus_genotype_2,_compl...    5601056.0    5493226.0
# NC_004102.1_Hepatitis_C_virus_genotype_1,_compl...    1398834.0     955098.0
# NC_001672.1_Tick-borne_encephalitis_virus,_comp...     786049.0     645084.0
# NC_009827.1_Hepatitis_C_virus_genotype_6,_compl...     743886.0     552712.0
# NC_015521.1_Cutthroat_trout_virus,_complete_genome     365011.0     304498.0
#
#                                                     donor2_day1  donor2_day2
# virus
# NC_009823.1_Hepatitis_C_virus_genotype_2,_compl...    5061926.0    6148410.0
# NC_004102.1_Hepatitis_C_virus_genotype_1,_compl...     917825.0    1056143.0
# NC_001672.1_Tick-borne_encephalitis_virus,_comp...     651190.0     688178.0
# NC_009827.1_Hepatitis_C_virus_genotype_6,_compl...     559024.0     601487.0
# NC_015521.1_Cutthroat_trout_virus,_complete_genome     301663.0     330356.0

# %%
df_virtect
# Out:
#                                                     donor1_day0  donor1_day1  \
# virus
# NC_009823.1_Hepatitis_C_virus_genotype_2,_compl...    5525018.0    6101557.0
# NC_004102.1_Hepatitis_C_virus_genotype_1,_compl...    1431200.0    1309365.0
# NC_001672.1_Tick-borne_encephalitis_virus,_comp...     863167.0     871020.0
# NC_009827.1_Hepatitis_C_virus_genotype_6,_compl...     767062.0     813529.0
# NC_015521.1_Cutthroat_trout_virus,_complete_genome     414053.0     414937.0
# NC_007605.1_Human_herpesvirus_4_complete_wild_t...       3485.0     364725.0
# NC_018382.1_Bat_hepevirus,_complete_genome             303949.0     297063.0
# NC_002645.1_Human_coronavirus_229E,_complete_ge...     266847.0     260944.0
# NC_018464.1_Shamonda_virus_N_and_NSs_genes,_seg...     167225.0     105493.0
# NC_009334.1_Human_herpesvirus_4,_complete_genome          854.0      82418.0
# gi|12084981|lcl|HPV71REF.1|_Human_papillomaviru...      38496.0      24061.0
# NC_018476.1_Simbu_virus_RdRp_gene_for_RNA-depen...      18078.0      10498.0
# NC_022518.1_Human_endogenous_retrovirus_K113_co...       5551.0       4383.0
# gi|2911558|lcl|HPV77REF.1|_Human_papillomavirus...       2122.0       3301.0
# NC_000898.1_Human_herpesvirus_6B,_complete_genome        3015.0       2246.0
# NC_014093.1_Torque_teno_midi_virus_2,_complete_...       2059.0       1949.0
# NC_001664.2_Human_herpesvirus_6A,_complete_genome        1976.0       1400.0
# gi|6970427|lcl|HPV82REF.1|_Human_papillomavirus...       1709.0       1183.0
# NC_001716.2_Human_herpesvirus_7,_complete_genome          531.0        945.0
# NC_003977.1_Hepatitis_B_virus,_complete_genome            578.0        482.0
# NC_001798.1_Human_herpesvirus_2,_complete_genome         1009.0        424.0
# NC_009824.1_Hepatitis_C_virus_genotype_3,_genome          413.0        401.0
# gi|9627396|lcl|HPV9REF.1|_Human_papillomavirus_...        634.0          0.0
# gi|396940|lcl|HPV19REF.1|_Human_papillomavirus_...        479.0          0.0
# NC_001669.1_Simian_virus_40,_complete_genome                0.0          0.0
#
#                                                     donor1_day2  donor2_day0  \
# virus
# NC_009823.1_Hepatitis_C_virus_genotype_2,_compl...    5601056.0    5493226.0
# NC_004102.1_Hepatitis_C_virus_genotype_1,_compl...    1398834.0     955098.0
# NC_001672.1_Tick-borne_encephalitis_virus,_comp...     786049.0     645084.0
# NC_009827.1_Hepatitis_C_virus_genotype_6,_compl...     743886.0     552712.0
# NC_015521.1_Cutthroat_trout_virus,_complete_genome     365011.0     304498.0
# NC_007605.1_Human_herpesvirus_4_complete_wild_t...     171694.0       2421.0
# NC_018382.1_Bat_hepevirus,_complete_genome             271494.0     232209.0
# NC_002645.1_Human_coronavirus_229E,_complete_ge...     237627.0     202240.0
# NC_018464.1_Shamonda_virus_N_and_NSs_genes,_seg...      70130.0     140009.0
# NC_009334.1_Human_herpesvirus_4,_complete_genome        46308.0        586.0
# gi|12084981|lcl|HPV71REF.1|_Human_papillomaviru...      16745.0      28291.0
# NC_018476.1_Simbu_virus_RdRp_gene_for_RNA-depen...       6414.0      20264.0
# NC_022518.1_Human_endogenous_retrovirus_K113_co...       3289.0       3212.0
# gi|2911558|lcl|HPV77REF.1|_Human_papillomavirus...       3790.0       1722.0
# NC_000898.1_Human_herpesvirus_6B,_complete_genome        2404.0       1253.0
# NC_014093.1_Torque_teno_midi_virus_2,_complete_...       2130.0       1238.0
# NC_001664.2_Human_herpesvirus_6A,_complete_genome        1937.0        585.0
# gi|6970427|lcl|HPV82REF.1|_Human_papillomavirus...        798.0       1231.0
# NC_001716.2_Human_herpesvirus_7,_complete_genome          434.0          0.0
# NC_003977.1_Hepatitis_B_virus,_complete_genome              0.0          0.0
# NC_001798.1_Human_herpesvirus_2,_complete_genome          478.0          0.0
# NC_009824.1_Hepatitis_C_virus_genotype_3,_genome          471.0          0.0
# gi|9627396|lcl|HPV9REF.1|_Human_papillomavirus_...          0.0        469.0
# gi|396940|lcl|HPV19REF.1|_Human_papillomavirus_...          0.0          0.0
# NC_001669.1_Simian_virus_40,_complete_genome             2676.0          0.0
#
#                                                     donor2_day1  donor2_day2
# virus
# NC_009823.1_Hepatitis_C_virus_genotype_2,_compl...    5061926.0    6148410.0
# NC_004102.1_Hepatitis_C_virus_genotype_1,_compl...     917825.0    1056143.0
# NC_001672.1_Tick-borne_encephalitis_virus,_comp...     651190.0     688178.0
# NC_009827.1_Hepatitis_C_virus_genotype_6,_compl...     559024.0     601487.0
# NC_015521.1_Cutthroat_trout_virus,_complete_genome     301663.0     330356.0
# NC_007605.1_Human_herpesvirus_4_complete_wild_t...     253708.0     132699.0
# NC_018382.1_Bat_hepevirus,_complete_genome             230962.0     243275.0
# NC_002645.1_Human_coronavirus_229E,_complete_ge...     196071.0     213983.0
# NC_018464.1_Shamonda_virus_N_and_NSs_genes,_seg...      71943.0      79160.0
# NC_009334.1_Human_herpesvirus_4,_complete_genome        60384.0      33900.0
# gi|12084981|lcl|HPV71REF.1|_Human_papillomaviru...      23785.0      15838.0
# NC_018476.1_Simbu_virus_RdRp_gene_for_RNA-depen...       9413.0      11517.0
# NC_022518.1_Human_endogenous_retrovirus_K113_co...       3216.0       2246.0
# gi|2911558|lcl|HPV77REF.1|_Human_papillomavirus...       3036.0       3502.0
# NC_000898.1_Human_herpesvirus_6B,_complete_genome        3591.0       1281.0
# NC_014093.1_Torque_teno_midi_virus_2,_complete_...       1462.0       1422.0
# NC_001664.2_Human_herpesvirus_6A,_complete_genome        2613.0        929.0
# gi|6970427|lcl|HPV82REF.1|_Human_papillomavirus...       1078.0        623.0
# NC_001716.2_Human_herpesvirus_7,_complete_genome          965.0        424.0
# NC_003977.1_Hepatitis_B_virus,_complete_genome              0.0          0.0
# NC_001798.1_Human_herpesvirus_2,_complete_genome            0.0          0.0
# NC_009824.1_Hepatitis_C_virus_genotype_3,_genome            0.0          0.0
# gi|9627396|lcl|HPV9REF.1|_Human_papillomavirus_...          0.0          0.0
# gi|396940|lcl|HPV19REF.1|_Human_papillomavirus_...          0.0          0.0
# NC_001669.1_Simian_virus_40,_complete_genome              516.0       1330.0

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df_virtect)
plt.savefig('img/vitect_heatmap.pdf', bbox_inches='tight')

# %% [markdown]
# ## kraken2

# %%
# list_donors = ['1', '2', '3']
list_donors = ['1', '2']
# list_days = ['0', '1', '2', '3', '4', '5', '8', '14']
list_days = ['0', '1', '2']

# %%
for donor in list_donors:
    for day in list_days:
        s = "donor{don}_day{day}".format(don=donor, day=day)
        d = pd.read_csv('kraken2_output/report_{}'.format(s), sep='\t', header=None)
        d.columns = ['percent', '-', s, 'code', 'ID', 'virus']
        d = d.loc[d['code'] == 'S', ['virus', s]]
        d = d[d[s] > 400]
        
        if s == "donor1_day0":
            df_kraken2 = d.copy()
        else:
            df_kraken2 = pd.merge(df_kraken2, d, how="outer")
df_kraken2 = df_kraken2.fillna(0)

df_kraken2.index = df_kraken2.virus
# df_virtect = df_virtect.drop('virus')
df_kraken2 = df_kraken2.drop(columns=['virus'])
df_kraken2 = df_kraken2.sort_values(by='donor1_day1', ascending=False)
df_kraken2.head()
# Out:
#                                                donor1_day0  donor1_day1  \
# virus
#         Choristoneura fumiferana granulovirus    3966956.0    2914766.0
#                   Shamonda orthobunyavirus       2201828.0    1456886.0
#             Proteus phage VB_PmiS-Isfahan        1976508.0     992575.0
#           BeAn 58058 virus                        981210.0     757478.0
#                   Simbu orthobunyavirus           912430.0     512488.0
#
#                                                donor1_day2  donor2_day0  \
# virus
#         Choristoneura fumiferana granulovirus    2190541.0    3964214.0
#                   Shamonda orthobunyavirus       1191705.0    2298833.0
#             Proteus phage VB_PmiS-Isfahan         884873.0    1606832.0
#           BeAn 58058 virus                        573996.0     773026.0
#                   Simbu orthobunyavirus           352971.0    1092670.0
#
#                                                donor2_day1  donor2_day2
# virus
#         Choristoneura fumiferana granulovirus    2945199.0    3243850.0
#                   Shamonda orthobunyavirus       1323261.0    1588355.0
#             Proteus phage VB_PmiS-Isfahan        1018019.0    1066110.0
#           BeAn 58058 virus                        712229.0     513598.0
#                   Simbu orthobunyavirus           534711.0     646383.0

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df_kraken2)
plt.savefig('img/kraken2_heatmap.pdf', bbox_inches='tight')
